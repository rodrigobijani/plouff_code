# %% [markdown]
# <font size="6px" font color="blue" face="Times New Roman"><b>Modelo Direto</b></font>

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
################PACOTES################
#% matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
#####################################

# %%
polygon= np.loadtxt(fname='polygon.txt', delimiter=',')
Pol=np.array(polygon)
n=len(Pol)

a=Pol[:,0]
b=Pol[:,1]
c=Pol[:,2]

print(x)
# Out:
# [ 0.1  0.1  0.2  0.1  0.1  0.1  0.2  0.1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(x,y,z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
print('Dados:')
print('número de vértices =',n)
print(Pol)
# Out:
# Dados:
# número de vértices = 8
# [[ 0.1  0.1  0.1]
#  [ 0.1  0.2  0.1]
#  [ 0.2  0.2  0.1]
#  [ 0.1  0.2  0.1]
#  [ 0.1  0.1  0.8]
#  [ 0.1  0.2  0.8]
#  [ 0.2  0.2  0.8]
#  [ 0.1  0.2  0.8]]
